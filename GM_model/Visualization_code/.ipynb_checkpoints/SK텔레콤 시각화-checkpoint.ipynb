# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### gm data 불러오기
# - gm계산코드 폴더 안에 gm계산 코드를 통해 gm 계산을 마친 데이터프레임은 gm_data에 csv 파일로 저장되어 있음

# %%
df = pd.read_csv("../gm_data/SK_gm_df.csv")

# %%
# 한글과 음수 부호가 제대로 표시되는 폰트로 변경
plt.rcParams['font.family'] = 'Arial Unicode MS'
plt.rcParams['axes.unicode_minus'] = False  # 음수 부호 표시 문제 해결

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 248 non-null    datetime64[ns]
#  1   영업이익(원)              248 non-null    int64
#  2   금융손익(비영업)(원)         248 non-null    int64
#  3   관계기업투자등관련손익(비영업)(원)  248 non-null    int64
#  4   종가(원)                248 non-null    int64
#  5   수정주가(원)              248 non-null    int64
#  6   PBR                  248 non-null    float64
#  7   us_10_treasury       248 non-null    float64
#  8   Quarter              248 non-null    object
#  9   equity               248 non-null    int64
#  10  세전이익                 248 non-null    int64
#  11  순이익                  248 non-null    float64
#  12  ROE                  248 non-null    float64
#  13  COE                  248 non-null    float64
#  14  gm                   248 non-null    float64
#  15  수정주가_1주후             243 non-null    float64
#  16  수정주가_2주후             238 non-null    float64
#  17  수정주가_1달후             228 non-null    float64
#  18  수정주가_3달후             188 non-null    float64
#  19  수익률_1주후              243 non-null    float64
#  20  수익률_2주후              238 non-null    float64
#  21  수익률_1달후              228 non-null    float64
#  22  수익률_3달후              188 non-null    float64
# dtypes: datetime64[ns](1), float64(14), int64(7), object(1)
# memory usage: 44.7+ KB

# %%
# 일주일뒤 수익률 시각화

# 그래프의 기본 틀 생성
fig, ax1 = plt.subplots(figsize=(10, 6))

# ax1에 '수익률_1주후' 그리기
color = 'tab:red'
ax1.set_xlabel('Date')
ax1.set_ylabel('수익률_1주후', color=color)
line1, = ax1.plot(df['Date'], df['수익률_1주후'], color=color, label='수익률_1주후')  # label 추가
ax1.tick_params(axis='y', labelcolor=color)

# ax2는 ax1과 x축을 공유하며 y축은 독립적으로 사용
ax2 = ax1.twinx()

# ax2에 'gm' 그리기
color = 'tab:blue'
ax2.set_ylabel('gm', color=color)
line2, = ax2.plot(df['Date'], df['gm'], color=color, label='gm')  # label 추가
ax2.tick_params(axis='y', labelcolor=color)

# 범례 추가
fig.legend(handles=[line1, line2], loc='upper left', bbox_to_anchor=(0.1, 0.95))  # 두 선의 범례를 추가

# 그래프 표시
plt.title("gm과 수익률_1주후 시각화")
plt.show()

# %%
# 2주뒤 수익률 시각화

# 그래프의 기본 틀 생성
fig, ax1 = plt.subplots(figsize=(10, 6))

# ax1에 '수익률_1주후' 그리기
color = 'tab:red'
ax1.set_xlabel('Date')
ax1.set_ylabel('수익률_2주후', color=color)
line1, = ax1.plot(df['Date'], df['수익률_2주후'], color=color, label='수익률_2주후')  # label 추가
ax1.tick_params(axis='y', labelcolor=color)

# ax2는 ax1과 x축을 공유하며 y축은 독립적으로 사용
ax2 = ax1.twinx()

# ax2에 'gm' 그리기
color = 'tab:blue'
ax2.set_ylabel('gm', color=color)
line2, = ax2.plot(df['Date'], df['gm'], color=color, label='gm')  # label 추가
ax2.tick_params(axis='y', labelcolor=color)

# 범례 추가
fig.legend(handles=[line1, line2], loc='upper left', bbox_to_anchor=(0.1, 0.95))  # 두 선의 범례를 추가

# 그래프 표시
plt.title("gm과 수익률_2주후 시각화")
plt.show()

# %%
# 1달뒤 수익률 시각화

# 그래프의 기본 틀 생성
fig, ax1 = plt.subplots(figsize=(10, 6))

# ax1에 '수익률_1주후' 그리기
color = 'tab:red'
ax1.set_xlabel('Date')
ax1.set_ylabel('수익률_1달후', color=color)
line1, = ax1.plot(df['Date'], df['수익률_1달후'], color=color, label='수익률_1달후')  # label 추가
ax1.tick_params(axis='y', labelcolor=color)

# ax2는 ax1과 x축을 공유하며 y축은 독립적으로 사용
ax2 = ax1.twinx()

# ax2에 'gm' 그리기
color = 'tab:blue'
ax2.set_ylabel('gm', color=color)
line2, = ax2.plot(df['Date'], df['gm'], color=color, label='gm')  # label 추가
ax2.tick_params(axis='y', labelcolor=color)

# 범례 추가
fig.legend(handles=[line1, line2], loc='upper left', bbox_to_anchor=(0.1, 0.95))  # 두 선의 범례를 추가

# 그래프 표시
plt.title("gm과 수익률_1달후 시각화")
plt.show()

# %%
sns.histplot(df['gm'], kde=True)
# Out:
# <Axes: xlabel='gm', ylabel='Count'>

# %%
sns.histplot(df['수익률_1달후'], kde=True)
# Out:
# <Axes: xlabel='수익률_1달후', ylabel='Count'>

# %%
# regplot으로 회귀선과 함께 산점도 그리기
sns.regplot(x='gm', y='수익률_1주후', data=df)

# 축 라벨과 타이틀 설정
plt.xlabel('gm')
plt.ylabel('수익률_1달후')
plt.title('gm 대비 수익률_1주후 회귀선')

# 그래프 출력
plt.show()

# %%
# regplot으로 회귀선과 함께 산점도 그리기
sns.regplot(x='gm', y='수익률_2주후', data=df)

# 축 라벨과 타이틀 설정
plt.xlabel('gm')
plt.ylabel('수익률_1달후')
plt.title('gm 대비 수익률_2주후 회귀선')

# 그래프 출력
plt.show()

# %%
# regplot으로 회귀선과 함께 산점도 그리기
sns.regplot(x='gm', y='수익률_1달후', data=df)

# 축 라벨과 타이틀 설정
plt.xlabel('gm')
plt.ylabel('수익률_1달후')
plt.title('gm 대비 수익률_1달후 회귀선')

# 그래프 출력
plt.show()
