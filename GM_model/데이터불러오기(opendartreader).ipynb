# %%
#pip install opendartreader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import OpenDartReader
import pandas as pd

# %%
# 모든 행을 보이게 설정
pd.set_option('display.max_rows', 50)

# %%
api_key = '84a439371a90d3e835db4df3f4db65f58cf9cb89'
dart = OpenDartReader(api_key)

# %%
df = dart.list('KB금융', start='2010-01-01')

# %%
dart.list('KB금융', start='2022-11-01')
# Out:
#    corp_code corp_name stock_code corp_cls  \
# 0   00688996      KB금융     105560        Y
# 1   00688996      KB금융     105560        Y
# 2   00688996      KB금융     105560        Y
# 3   00688996      KB금융     105560        Y
# 4   00688996      KB금융     105560        Y
# ..       ...       ...        ...      ...
# 76  00688996      KB금융     105560        Y
# 77  00688996      KB금융     105560        Y
# 78  00688996      KB금융     105560        Y
# 79  00688996      KB금융     105560        Y
# 80  00688996      KB금융     105560        Y
#
#                               report_nm        rcept_no  flr_nm  rcept_dt rm
# 0                             현금ㆍ현물배당결정  20231024800261    KB금융  20231024  유
# 1   연결재무제표기준영업(잠정)실적(공정공시)(자회사의 주요경영사항)  20231024800247    KB금융  20231024  유
# 2   연결재무제표기준영업(잠정)실적(공정공시)(자회사의 주요경영사항)  20231024800243    KB금융  20231024  유
# 3                연결재무제표기준영업(잠정)실적(공정공시)  20231024800240    KB금융  20231024  유
# ...

# %%
# 반기, 분기, 사업 보고서만 추출
df = df[df['report_nm'].str.contains('반기보고서|분기보고서|사업보고서')]

# %%
df['report_nm'].unique()
# Out:
# array(['[기재정정]반기보고서 (2023.06)', '[기재정정]분기보고서 (2023.03)',
#        '[기재정정]사업보고서 (2022.12)', '해외증권거래소등에신고한사업보고서등의국내신고',
#        '분기보고서 (2022.09)', '반기보고서 (2022.06)', '분기보고서 (2022.03)',
#        '[기재정정]사업보고서 (2021.12)', '분기보고서 (2021.09)', '반기보고서 (2021.06)',
#        '분기보고서 (2021.03)', '[기재정정]사업보고서 (2020.12)',
#        '[기재정정]분기보고서 (2020.09)', '[기재정정]반기보고서 (2020.06)',
#        '[기재정정]분기보고서 (2020.03)', '[기재정정]사업보고서 (2019.12)',
#        '[기재정정]분기보고서 (2019.09)', '[기재정정]반기보고서 (2019.06)',
#        '[기재정정]분기보고서 (2019.03)', '[기재정정]사업보고서 (2018.12)',
#        '[기재정정]분기보고서 (2018.09)', '[기재정정]반기보고서 (2018.06)',
#        '[기재정정]분기보고서 (2018.03)', '[기재정정]사업보고서 (2017.12)',
#        '[기재정정]분기보고서 (2017.09)', '[기재정정]반기보고서 (2017.06)',
#        '[기재정정]분기보고서 (2017.03)', '사업보고서 (2016.12)', '분기보고서 (2016.09)',
#        '반기보고서 (2016.06)', '분기보고서 (2016.03)', '[첨부정정]사업보고서 (2015.12)',
#        '분기보고서 (2015.09)', '반기보고서 (2015.06)', '[기재정정]사업보고서 (2014.12)',
# ...

# %%
# '해외증권거래소등에신고한사업보고서등의국내신고' 제거
df = df[df['report_nm'] != '해외증권거래소등에신고한사업보고서등의국내신고']

# %%
df['report_nm'].unique()
# Out:
# array(['[기재정정]반기보고서 (2023.06)', '[기재정정]분기보고서 (2023.03)',
#        '[기재정정]사업보고서 (2022.12)', '분기보고서 (2022.09)', '반기보고서 (2022.06)',
#        '분기보고서 (2022.03)', '[기재정정]사업보고서 (2021.12)', '분기보고서 (2021.09)',
#        '반기보고서 (2021.06)', '분기보고서 (2021.03)', '[기재정정]사업보고서 (2020.12)',
#        '[기재정정]분기보고서 (2020.09)', '[기재정정]반기보고서 (2020.06)',
#        '[기재정정]분기보고서 (2020.03)', '[기재정정]사업보고서 (2019.12)',
#        '[기재정정]분기보고서 (2019.09)', '[기재정정]반기보고서 (2019.06)',
#        '[기재정정]분기보고서 (2019.03)', '[기재정정]사업보고서 (2018.12)',
#        '[기재정정]분기보고서 (2018.09)', '[기재정정]반기보고서 (2018.06)',
#        '[기재정정]분기보고서 (2018.03)', '[기재정정]사업보고서 (2017.12)',
#        '[기재정정]분기보고서 (2017.09)', '[기재정정]반기보고서 (2017.06)',
#        '[기재정정]분기보고서 (2017.03)', '사업보고서 (2016.12)', '분기보고서 (2016.09)',
#        '반기보고서 (2016.06)', '분기보고서 (2016.03)', '[첨부정정]사업보고서 (2015.12)',
#        '분기보고서 (2015.09)', '반기보고서 (2015.06)', '[기재정정]사업보고서 (2014.12)',
#        '분기보고서 (2015.03)', '분기보고서 (2014.09)', '반기보고서 (2014.06)',
# ...

# %%
# 특정기업(삼성전자) 1999년~이후 모든 정기보고서 (최종보고서)
dart.list('KB금융', start='2010-01-01', kind='A')
# Out:
#    corp_code corp_name stock_code corp_cls              report_nm  \
# 0   00688996      KB금융     105560        Y  [기재정정]반기보고서 (2023.06)
# 1   00688996      KB금융     105560        Y  [기재정정]분기보고서 (2023.03)
# 2   00688996      KB금융     105560        Y  [기재정정]사업보고서 (2022.12)
# 3   00688996      KB금융     105560        Y        분기보고서 (2022.09)
# 4   00688996      KB금융     105560        Y        반기보고서 (2022.06)
# ..       ...       ...        ...      ...                    ...
# 50  00688996      KB금융     105560        Y        사업보고서 (2010.12)
# 51  00688996      KB금융     105560        Y  [기재정정]분기보고서 (2010.09)
# 52  00688996      KB금융     105560        Y        반기보고서 (2010.06)
# 53  00688996      KB금융     105560        Y        분기보고서 (2010.03)
# 54  00688996      KB금융     105560        Y        사업보고서 (2009.12)
#
#           rcept_no flr_nm  rcept_dt rm
# 0   20231005000482   KB금융  20231005
# 1   20231005000478   KB금융  20231005
# 2   20231005000471   KB금융  20231005  연
# ...
