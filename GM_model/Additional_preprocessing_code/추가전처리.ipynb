# %% [markdown]
# ### 추가 전처리 코드
#
# - Input: gm게산 코드를 통해 생성된 csv file (gm_data 폴더에 존재)
# - Precess: 아웃라이어 발견, Stationary하게 데이터 수정 등의 추가 전처리 진행하는 코드
# - Output: 시각화에 사용할 csv file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../gm_data/SK_gm_df.csv")

# %%
df
# Out:
#            Date        영업이익(원)  금융손익(비영업)(원)  관계기업투자등관련손익(비영업)(원)  종가(원)  \
# 0    2022-07-01  1357569000000 -191014000000         -75909000000  52800
# 1    2022-07-04  1357569000000 -191014000000         -75909000000  53600
# 2    2022-07-05  1357569000000 -191014000000         -75909000000  54200
# 3    2022-07-06  1357569000000 -191014000000         -75909000000  53800
# 4    2022-07-07  1357569000000 -191014000000         -75909000000  53800
# ..          ...            ...           ...                  ...    ...
# 242  2023-06-23   958187000000  -97545000000           9672000000  47400
# 243  2023-06-26   958187000000  -97545000000           9672000000  47350
# 244  2023-06-27   958187000000  -97545000000           9672000000  47600
# 245  2023-06-28   958187000000  -97545000000           9672000000  47650
# 246  2023-06-29   958187000000  -97545000000           9672000000  46250
#
#      수정주가(원)   PBR  us_10_treasury Quarter          equity  ...  \
# ...
